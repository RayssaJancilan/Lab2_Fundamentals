# %%
# Activity 1: Redaction Protocol
TARGET_NAME = "JANCILAN"
SURNAME = "JANCILAN"
for letter in SURNAME:
    print(letter)

STUDENT_ID = "TUPM-26-3228"

SEED_NUM = int(STUDENT_ID[-1])
redacted_name = ""
for character in TARGET_NAME:
    if character in "AEIOU":
       print(f"{redacted_name}{SEED_NUM}")
    else:
        print(f"{redacted_name}{character}")
# Out:
# J
# A
# N
# C
# I
# L
# A
# N
# J
# 8
# N
# C
# 8
# L
# 8
# N

# %%
# Activity 2 : Forensic Signature
ENGINEER = "JANCILAN" 
First_letter = "JANCILAN"[0]

# A = ASCII Value of first letter
ASCII = ord(First_letter)
# B = SEED_NUM
SEED_NUM = 8
# C = loops from task 14
loops = 11

verification_hash = (ASCII * SEED_NUM) - loops

print(f"forensic signature: {verification_hash}")
# Out:
# forensic signature: 581

# %%
# Activity 3

correct_password = "********"

attempts = 0
max_attempts = 3

while attempts < max_attempts:
    pwd = input("Type '********' to exit: ")
    attempts += 1
    if pwd == correct_password:
        print("Unlocked")
        break
    else: 
        print("Access Denied")

        print(f"Total Number of attempts: {attempts}")
# Out:
# Access Denied
# Total Number of attempts: 1
# Access Denied
# Total Number of attempts: 2
# Unlocked
